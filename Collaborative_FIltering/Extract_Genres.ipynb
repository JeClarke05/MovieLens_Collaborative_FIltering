# %%
# Import Python libraries
import numpy as np 
import pandas as pd

# %%
movies = pd.read_csv("Data/movies.csv", low_memory=False)

# %%
Horror = movies[movies['genres'].str.contains("Horror")]
Horror.head(5)
# Out:
#     movieId                          title_year                        title  \
# 11       12  Dracula: Dead and Loving It (1995)  Dracula: Dead and Loving It
# 21       22                      Copycat (1995)                      Copycat
# 69       70          From Dusk Till Dawn (1996)          From Dusk Till Dawn
# 90       92                  Mary Reilly (1996)                  Mary Reilly
# 91       93          Vampire in Brooklyn (1995)          Vampire in Brooklyn
#
#                                  genres
# 11                        Comedy|Horror
# 21  Crime|Drama|Horror|Mystery|Thriller
# 69        Action|Comedy|Horror|Thriller
# 90                Drama|Horror|Thriller
# 91                Comedy|Horror|Romance

# %%
Horror.to_csv('Data/Horror.csv')

# %%
Adventure = movies[movies['genres'].str.contains("Adventure")]
Adventure.head(5)
# Out:
#     movieId           title_year         title  \
# 0         1     Toy Story (1995)     Toy Story
# 1         2       Jumanji (1995)       Jumanji
# 7         8  Tom and Huck (1995)  Tom and Huck
# 9        10     GoldenEye (1995)     GoldenEye
# 12       13         Balto (1995)         Balto
#
#                                          genres
# 0   Adventure|Animation|Children|Comedy|Fantasy
# 1                    Adventure|Children|Fantasy
# 7                            Adventure|Children
# 9                     Action|Adventure|Thriller
# 12                 Adventure|Animation|Children

# %%
Adventure.to_csv('Data/Adventure.csv')

# %%
Comedy = movies[movies['genres'].str.contains("Comedy")]
Comedy.head(5)
# Out:
#    movieId                          title_year                        title  \
# 0        1                    Toy Story (1995)                    Toy Story
# 2        3             Grumpier Old Men (1995)             Grumpier Old Men
# 3        4            Waiting to Exhale (1995)            Waiting to Exhale
# 4        5  Father of the Bride Part II (1995)  Father of the Bride Part II
# 6        7                      Sabrina (1995)                      Sabrina
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 6                               Comedy|Romance

# %%
Comedy.to_csv('Data/Comedy.csv')

# %%
Fantasy = movies[movies['genres'].str.contains("Fantasy")]
Fantasy.head(5)
# Out:
#     movieId                                         title_year  \
# 0         1                                   Toy Story (1995)
# 1         2                                     Jumanji (1995)
# 28       29  City of Lost Children, The (Cité des enfants p...
# 43       44                               Mortal Kombat (1995)
# 55       56                     Kids of the Round Table (1995)
#
#                         title                                       genres
# 0                   Toy Story  Adventure|Animation|Children|Comedy|Fantasy
# 1                     Jumanji                   Adventure|Children|Fantasy
# 28  The City of Lost Children       Adventure|Drama|Fantasy|Mystery|Sci-Fi
# 43              Mortal Kombat                     Action|Adventure|Fantasy
# 55    Kids of the Round Table            Adventure|Children|Comedy|Fantasy

# %%
Fantasy.to_csv('Data/Fantasy.csv')
